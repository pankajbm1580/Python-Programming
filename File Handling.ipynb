# %%
f = open('Record.txt') ### defualt mode is 'r'

# %%
data = f.read()

# %%
print(data)
# Out:
# ' Pankaj'
# 'Niraj'
# 'London'
# 'Paris'

# %%
f = open('Record.txt')
for _ in range(10):
    chunk = f.read(40)
    print(chunk)
# Out:
# ' Pankaj'
# 'Niraj'
# 'London'
# 'Paris'

# %%
f = open('Record.txt')
records = f.readlines()

for rec in records:
    print(rec)
# Out:
# ' Pankaj'
#
# 'Niraj'
#
# 'London'
#
# 'Paris'

# %%
f = open('data.csv')
data1 = f.read()
print(data1)
# Out:
# *** Test Cases ***,${username},${password}
# Invalid username,dsahed,learning
# Invalid password,rahulshettyacademy,ploudfg
# special characters,@#$,552

# %%
f = open('data.csv')
records = f.readlines()
print(len(records))
# Out:
# 4

# %%
import pandas as pd  # df is dataframe
df = pd.read_csv('data.csv')
df.columns
df.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 import pandas as pd
#       2 df = pd.read_csv('data.csv')
#       3 df.columns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
f2 = open('Employee.txt', 'w')

# %%
f2.write('Sudhanshu')
# Out:
# 9

# %%
f2.close()

# %%
xyz = open('Employee.txt', 'w')

# %%
xyz.write('rakesh pundit')
# Out:
# 13

# %%
xyz.close()

# %%
f3 = open('Employee.txt', 'w')
lst =['amit\n' , 'akash\n' , 'vinod\n' ]
f3.writelines(lst)
f3.close()

# %%
pqr = open('Employee.txt' , 'a')
lst =['sumit\n' , 'prakash\n' , 'binod\n' ]
pqr.writelines(lst)
pqr.close()

# %%
import shutil
source = 'Employee.txt'
destination ='Employee2.txt'
shutil.copy(source, destination)
# Out:
# 'Employee2.txt'
