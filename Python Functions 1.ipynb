# %%
def square(num):
    return num * num

# %%
square(6)
# Out:
# 36

# %%
func = lambda a, b : a+b
func(10,20)
# Out:
# 30

# %%
a =[1,2,3]
b = [4,8, 12]

result = map (lambda x, y : x+y , a, b)
print(list(result))
# Out:
# [5, 10, 15]

# %%
list1 = [12,14,16, 18, 20]
list2 = list(map(lambda x: x*4, list1))
print(list2)
# Out:
# [48, 56, 64, 72, 80]

# %% [markdown]
# ## Nested Function

# %%
def outer():
    print('Outer Functions Started')
    def inner():
        print('Inner Functions started')
    print('Outer Fubction calling Inner Fubctions')
    print('Outer number Fubction calling Inner Fubctions')
    return inner

# %%
def outer():
    print('Outer Functions Started')
    def inner():
        print('Inner Functions started')
    print('Outer Fubction calling Inner Fubctions')
    print('Outer number Fubction calling Inner Fubctions')
    return outer

# %%
func = outer()
# Out:
# Outer Functions Started
# Outer Fubction calling Inner Fubctions
# Outer number Fubction calling Inner Fubctions

# %%
func()
# Out:
# Inner Functions started

# %%
def addition(a,b):
    print(a+b)

result = addition(10,20)
print(result*2)
# Out:
# 30
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       2     print(a+b)
#       4 result = addition(10,20)
# ----> 5 print(result*2)
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %%
def addition(a,b):
    return a+b

result = addition(10,20)
print(result *2)
# Out:
# 60

# %% [markdown]
# ## Function decorators

# %%
def Ordinary():
    print('i am an ordinary person')

# %%
Ordinary()
# Out:
# i am an ordinary person

# %%
def makemeoprettry(func): - this is decorator function. we are calling one function within te bracket.`
    def inner_fub():
        print('Now I am pretty')
        func()
    return inner_fub

# %%
func = Ordinary
func()
pretty = makemeoprettry(Ordinary)
pretty()
# Out:
# i am an ordinary person
# Now I am pretty
# i am an ordinary person
