# %%
import logging
logging.basicConfig(filename='log.txt' , level=logging.WARNING)
print("Logging Module Demo")
logging.debug("This sis a debug message")
logging.info("This sis a info message")
logging.warning("This sis a warnking message")
logging.error("This sis a error message")
logging.critical("This sis a critical message")
# Out:
# Logging Module Demo

# %%
# !pip install pandas
