# %% [markdown]
# ## local variable and Global variable
# if you define anything within the function then its local variable
# if you define anything outside the function then its called global variable
